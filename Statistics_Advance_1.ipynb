# %% [markdown]
#                         Statistics Advance Part 1
# 1. Random Variables & Their Types
# Random Variable: A function mapping outcomes of a random experiment to numerical values.
#
# -Types of Random Variables:
#
# -Discrete: Takes countable values (e.g., dice rolls 🎲).
#
# -Continuous: Takes any value within an interval (e.g., temperature 🌡️).
#
# 2.  Discrete vs. Continuous Distributions
# Feature	                     Discrete	      Continuous
# Values	                     Countable	    Infinite within a range
# Probability Calculation
#                              P(X=x)          Area under f(x)f(x
#
# Example	                     coin flips	     Height of people
#
# 3.  Probability Distributions
# Probability Distribution Function (PDF):
#
# Discrete: Probability Mass Function (PMF) gives exact probabilities.
#
# Continuous: Probability Density Function (PDF) represents density over an interval.
#
# Cumulative Distribution Function (CDF):
#
# Gives the probability that a random variable is ≤ a given value.
#
# Always increasing, ranging from 0 to 1.
#
# 4. A Probability Distribution Function (PDF) describes how the probability of a continuous random variable is distributed over its possible values.
#
# 5. Probability Distributions
# Probability Distribution Function (PDF):
#
# Discrete: Probability Mass Function (PMF) gives exact probabilities.
#
# Continuous: Probability Density Function (PDF) represents density over an interval.
#
# 6.Discrete Uniform Distribution: Equal probability for all possible values (e.g., rolling a fair die 🎲
#
# 7. Bernoulli Distribution:
#
# Models a single success/failure event (e.g., coin flip).
#
# Key property:
# 𝑃
# (
# 𝑋
# =
# 1
# )
# =
# 𝑝
# P(X=1)=p,
# 𝑃
# (
# 𝑋
# =
# 0
# )
# =
# 1
# −
# 𝑝
# P(X=0)=1−p
#
# 8. Binomial Distribution:
#
# Models
# 𝑛
# n independent Bernoulli trials.
#
# Used for counting successes (e.g., number of heads in 10 coin flips).
#
# 9. Poisson Distribution:
#
# Models count of rare events over time (e.g., calls to a call center
#
# 10. Continuous Uniform Distribution:
#
# All values in an interval have equal probability (e.g., random number between 0 and 1).
#
# 11. Normal Distribution:
#
# Bell-shaped, symmetric, governed by mean
# 𝜇
# μ and standard deviation
# 𝜎
# σ
#
# 12. Standard Normal Distribution:
#
# Normalized to mean 0, standard deviation 1.
#
# Used in Z-score calculations.
#
# 13. Central Limit Theorem (CLT) & Z-Scores
# CLT:
#
# The sum/average of a large number of independent random variables tends to follow a normal distribution.
#
# 14. The Central Limit Theorem (CLT) states that the sampling distribution of the sample mean approaches a normal distribution, regardless of the original population distribution, as the sample size increases.
#
# 15. Z-Statistics & Z-Scores:
#
# Standardized measure of deviation from the mean.
#
# Used in hypothesis testing & confidence intervals.
#
# 16. Calculating a Z-score:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# Measures how far
# 𝑋
# X is from the mean
# 𝜇
# μ in standard deviation units.
#
# 17. Estimation & Confidence Intervals
# Point Estimate: A single best guess for a population parameter.
#
# Interval Estimate (Confidence Interval):
#
# Provides a range where the true parameter likely lies.
#
# Linked to Z-scores.
#
# 18. A confidence interval (CI) is a range of values used to estimate an unknown population parameter (e.g., mean or proportion) with a certain level of confidence.
#
# 19. Why Are Confidence Intervals Important?
# - Provide a Range Instead of a Single Estimate
#
# Instead of just giving a single sample mean (
# 𝑥
# ˉ
# x
# ˉ
#  ) as an estimate, a CI gives a range where the true population mean (
# 𝜇
# μ) is likely to lie.
#
# - Incorporate Variability & Uncertainty
#
# Confidence intervals account for sampling variability, showing that repeated samples would give slightly different estimates.
#
# - Help in Decision Making
#
# If a confidence interval for a drug’s effectiveness does not include zero, researchers can conclude it is likely effective.
#
# If two group means' CIs overlap significantly, there may be no significant difference between them.
#
# - Linked to Hypothesis Testing
#
# A 95% confidence interval corresponds to a 5% significance level in hypothesis testing.
#
# If a null hypothesis value (e.g., a mean difference of 0) is outside the confidence interval, we reject the null hypothesis.

# %%
                                                  pratical questions

# %%
import numpy as np

# Generate a random integer between 1 and 10
random_value = np.random.randint(1, 11)
print("Random Variable:", random_value)
# Out:
# Random Variable: 4

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import randint

# Generate discrete uniform distribution (1 to 6)
low, high = 1, 6
samples = randint.rvs(low, high+1, size=10000)

# PMF Calculation
values, counts = np.unique(samples, return_counts=True)
pmf = counts / counts.sum()

# Plot PMF
plt.bar(values, pmf, color='blue', alpha=0.7, label="PMF")
plt.xlabel("Values")
plt.ylabel("Probability")
plt.title("Discrete Uniform Distribution (1-6)")
plt.legend()
plt.show()

# %%
from scipy.stats import bernoulli

def bernoulli_pdf(p, x):
    return bernoulli.pmf(x, p)

# Example
p = 0.5
x_values = [0, 1]
pdf_values = [bernoulli_pdf(p, x) for x in x_values]

print("Bernoulli PDF values:", pdf_values)
# Out:
# Bernoulli PDF values: [np.float64(0.5000000000000001), np.float64(0.5)]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n, p = 10, 0.5
data = binom.rvs(n, p, size=1000)

# Plot histogram
plt.hist(data, bins=np.arange(n+2)-0.5, density=True, alpha=0.6, color='blue', label="Simulated Data")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

lam = 5  # Average rate
data = poisson.rvs(mu=lam, size=1000)

# Plot histogram
plt.hist(data, bins=15, density=True, alpha=0.6, color='green', label="Simulated Data")
plt.xlabel("Occurrences")
plt.ylabel("Probability")
plt.title("Poisson Distribution (λ=5)")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

low, high = 1, 6
samples = randint.rvs(low, high+1, size=10000)

# Compute CDF
values, counts = np.unique(samples, return_counts=True)
cdf = np.cumsum(counts) / counts.sum()

# Plot CDF
plt.step(values, cdf, where="post", color="red", label="CDF")
plt.xlabel("Values")
plt.ylabel("Cumulative Probability")
plt.title("Cumulative Distribution Function (Discrete Uniform)")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate uniform data
data = np.random.uniform(0, 1, 10000)

# Plot histogram
plt.hist(data, bins=50, density=True, color='purple', alpha=0.6)
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Continuous Uniform Distribution")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

mean, std_dev = 0, 1
data = np.random.normal(mean, std_dev, 10000)

# Plot histogram
plt.hist(data, bins=50, density=True, alpha=0.6, color='orange')
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Normal Distribution Histogram")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Generate random dataset
data = np.random.normal(50, 15, 1000)

# Compute Z-scores
z_scores = zscore(data)

# Plot histogram of Z-scores
plt.hist(z_scores, bins=50, density=True, alpha=0.6, color='brown')
plt.xlabel("Z-Score")
plt.ylabel("Density")
plt.title("Z-Score Distribution")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
population_size = 10000
sample_size = 30
num_samples = 1000

# Generate non-normal population (exponential)
population = np.random.exponential(scale=2, size=population_size)

# Generate sample means
sample_means = [np.mean(np.random.choice(population, sample_size)) for _ in range(num_samples)]

# Plot histogram
plt.hist(sample_means, bins=50, density=True, alpha=0.6, color='blue')
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.title("Central Limit Theorem Demonstration")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Population from a normal distribution
pop_mean, pop_std = 50, 15
population = np.random.normal(pop_mean, pop_std, 10000)

# Draw multiple samples and compute means
sample_size = 30
num_samples = 1000
sample_means = [np.mean(np.random.choice(population, sample_size)) for _ in range(num_samples)]

# Plot histogram
plt.hist(sample_means, bins=50, density=True, alpha=0.6, color='blue')
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.title("Central Limit Theorem Verification")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

x = np.linspace(-4, 4, 1000)
pdf = norm.pdf(x, loc=0, scale=1)

plt.plot(x, pdf, label="Standard Normal PDF", color='red')
plt.xlabel("X")
plt.ylabel("Probability Density")
plt.title("Standard Normal Distribution (Mean=0, Std=1)")
plt.legend()
plt.show()

# %%
from scipy.stats import binom

n, p = 10, 0.5
x = np.arange(0, n+1)
probs = binom.pmf(x, n, p)

print("Binomial Probabilities:", probs)

plt.bar(x, probs, color='blue', alpha=0.6)
plt.xlabel("Successes")
plt.ylabel("Probability")
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.show()
# Out:
# Binomial Probabilities: [0.00097656 0.00976563 0.04394531 0.1171875  0.20507812 0.24609375
#  0.20507812 0.1171875  0.04394531 0.00976563 0.00097656]

# %%
from scipy.stats import norm

# Sample data
sample_mean = 52
pop_mean = 50
pop_std = 10
n = 30

# Compute Z-statistic
z = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
p_value = 1 - norm.cdf(z)

print(f"Z-score: {z:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject the null hypothesis (significant difference).")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Z-score: 1.0954
# P-value: 0.1367
# Fail to reject the null hypothesis.

# %%
import numpy as np
import scipy.stats as stats

data = np.random.normal(50, 10, 100)
mean, std = np.mean(data), np.std(data, ddof=1)
confidence = 0.95

margin_error = stats.norm.ppf((1 + confidence) / 2) * (std / np.sqrt(len(data)))
lower, upper = mean - margin_error, mean + margin_error

print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# 95% Confidence Interval: (47.75, 51.38)

# %%
import numpy as np
import scipy.stats as stats

sample = np.random.normal(100, 15, 50)
mean, std = np.mean(sample), np.std(sample, ddof=1)
conf_int = stats.norm.interval(0.95, loc=mean, scale=std/np.sqrt(len(sample)))

print(f"95% Confidence Interval for Mean: {conf_int}")
# Out:
# 95% Confidence Interval for Mean: (np.float64(95.21284494480285), np.float64(104.2134286754826))

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

x = np.linspace(70, 130, 100)
pdf = norm.pdf(x, loc=100, scale=15)

plt.plot(x, pdf, color="green")
plt.title("Normal Distribution PDF")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
from scipy.stats import poisson
import numpy as np
import matplotlib.pyplot as plt

lambda_value = 5
x = np.arange(0, 15)
cdf = poisson.cdf(x, lambda_value)

plt.plot(x, cdf, marker="o", linestyle="-", color="blue")
plt.xlabel("X")
plt.ylabel("Cumulative Probability")
plt.title("Poisson Distribution CDF (λ=5)")
plt.show()

# %%
import numpy as np

data = np.random.uniform(0, 10, 1000)
expected_value = np.mean(data)

print(f"Expected Value: {expected_value:.2f}")
# Out:
# Expected Value: 4.98

# %%
import numpy as np
import matplotlib.pyplot as plt

data1 = np.random.normal(50, 10, 1000)
data2 = np.random.normal(50, 20, 1000)

std1, std2 = np.std(data1), np.std(data2)
print(f"Standard Deviations: Dataset 1 = {std1:.2f}, Dataset 2 = {std2:.2f}")

plt.hist(data1, bins=50, alpha=0.5, label="Std=10")
plt.hist(data2, bins=50, alpha=0.5, label="Std=20")
plt.legend()
plt.show()
# Out:
# Standard Deviations: Dataset 1 = 10.15, Dataset 2 = 19.38

# %%
import numpy as np

data = np.random.normal(50, 10, 1000)
range_value = np.ptp(data)
iqr_value = np.percentile(data, 75) - np.percentile(data, 25)

print(f"Range: {range_value:.2f}")
print(f"Interquartile Range (IQR): {iqr_value:.2f}")
# Out:
# Range: 66.18
# Interquartile Range (IQR): 14.26

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

data = np.random.normal(50, 15, 1000)
normalized_data = zscore(data)

plt.hist(normalized_data, bins=50, color='blue', alpha=0.6)
plt.title("Z-score Normalized Data")
plt.xlabel("Z-score")
plt.ylabel("Density")
plt.show()

# %%
import numpy as np
from scipy.stats import skew, kurtosis

data = np.random.normal(50, 15, 1000)
skewness = skew(data)
kurt = kurtosis(data)

print(f"Skewness: {skewness:.2f}")
print(f"Kurtosis: {kurt:.2f}")
# Out:
# Skewness: -0.10
# Kurtosis: -0.02
